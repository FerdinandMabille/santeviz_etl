# %%
import pandas as pd
from simpledbf import Dbf5
# Out:
# PyTables is not installed. No support for HDF output.
# SQLalchemy is not installed. No support for SQL output.

# %%
# Importation des données et conversion de dbf à dataframe
dbf = Dbf5('ucd_total_00603_20220527.dbf', codec='latin')
dbf

# %%
df = dbf.to_dataframe()

# %%
df
# Out:
#       CODE_UCD LISTE                                          NOM_COURT  \
# 0      9316207     R  CARBOPLATINE ACTAVIS 10 MG/ML Solution pour pe...
# 1      9316213     R  CARBOPLATINE ACTAVIS 10 MG/ML Solution pour pe...
# 2      9316236     R  CARBOPLATINE ACTAVIS 10 MG/ML Solution pour pe...
# 3      9316242     R  CARBOPLATINE ACTAVIS 10 MG/ML Solution pour pe...
# 4      9316710     R  FLUDARABINE ACTAVIS 25 MG/ML Poudre pour solut...
# ...        ...   ...                                                ...
# 2705   9457178     R                      EPIRUBICINE HIK 2MG/ML FL10ML
# 2706   9457184     R                     EPIRUBICINE HIK 2MG/ML FL100ML
# 2707   9457190     R                      EPIRUBICINE HIK 2MG/ML FL25ML
# 2708   9457209     R                       EPIRUBICINE HIK 2MG/ML FL5ML
# 2709   9876544     T      BEVACIZUMAB 25 MG/ML DMLA Seringue de 0.10 mL
#
#       DT_DINSCRI  DT_FINSCRI  MOTIF_FIN        LABO_EXP  DT_SOURDOC  \
# ...

# %%
df.to_csv(path_or_buf='C:\\Users\\ferdinand.mabille\\Documents\\Projets\\Santéviz\\20-POC AVC UNV\\00-Conception\\Python\\dbf\\ucd.csv', index = False, sep= ';', encoding='latin')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2710 entries, 0 to 2709
# Data columns (total 45 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CODE_UCD    2710 non-null   int64
#  1   LISTE       2710 non-null   object
#  2   NOM_COURT   2710 non-null   object
#  3   DT_DINSCRI  2710 non-null   object
#  4   DT_FINSCRI  722 non-null    object
#  5   MOTIF_FIN   722 non-null    object
#  6   LABO_EXP    2710 non-null   object
#  7   DT_SOURDOC  2710 non-null   object
#  8   DT_APPRIX   2710 non-null   object
#  9   PRIX_HT     2464 non-null   float64
#  10  PRIX_TTC    2464 non-null   float64
#  11  T_FACTURE   2020 non-null   object
#  12  MARGE_TTC   2017 non-null   float64
#  13  DT_APTAUX   2020 non-null   object
#  14  TAUX        2020 non-null   float64
#  15  DT_DCOUSUP  424 non-null    object
#  16  DT_FCOUSUP  0 non-null      float64
#  17  DT_APMAJO   2710 non-null   object
#  18  MAJO_971    2710 non-null   float64
# ...

# %%
new_df = pd.DataFrame()
new_df['code_ucd'] = df['CODE_UCD']
new_df['libelle_traitement'] = df['NOM_COURT']
new_df['type']=''
new_df
# Out:
#       code_ucd                                 libelle_traitement type
# 0      9316207  CARBOPLATINE ACTAVIS 10 MG/ML Solution pour pe...
# 1      9316213  CARBOPLATINE ACTAVIS 10 MG/ML Solution pour pe...
# 2      9316236  CARBOPLATINE ACTAVIS 10 MG/ML Solution pour pe...
# 3      9316242  CARBOPLATINE ACTAVIS 10 MG/ML Solution pour pe...
# 4      9316710  FLUDARABINE ACTAVIS 25 MG/ML Poudre pour solut...
# ...        ...                                                ...  ...
# 2705   9457178                      EPIRUBICINE HIK 2MG/ML FL10ML
# 2706   9457184                     EPIRUBICINE HIK 2MG/ML FL100ML
# 2707   9457190                      EPIRUBICINE HIK 2MG/ML FL25ML
# 2708   9457209                       EPIRUBICINE HIK 2MG/ML FL5ML
# 2709   9876544      BEVACIZUMAB 25 MG/ML DMLA Seringue de 0.10 mL
#
# [2710 rows x 3 columns]

# %%
new_df.to_csv(path_or_buf='C:\\Users\\ferdinand.mabille\\Documents\\Projets\\Santéviz\\20-POC AVC UNV\\00-Conception\\Python\\dbf\\dmt_avc_unv_dim_traitement.csv', index = False, sep= ';', encoding='latin')
